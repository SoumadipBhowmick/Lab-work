# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
V=[4.89,4.17,3.69,3.30,2.75,1.94,1.42,1.18,0.44,0.18]
I=[0,0,0,0.01,0.01,0.02,0.02,0.03,0.04,0.04]
V1=[-0.53,-0.64,-0.70,-0.72]
I1=[0.05,0.05,0.05,0.05]
def f(x,a,b):
    return a*x+b
popt,pcov=curve_fit(f,V,I)
xFit=np.arange(0,4.5,0.1)
'''def f2(x,a,b):
    return a*np.log(x)+b
popt,pcov=curve_fit(f2,V1,I1)
XFit2=np.arange(-0.72,0,0.01)'''
ax=plt.axes()
ax.invert_xaxis()
plt.plot(V,I,'k.')
plt.plot(xFit,f(xFit,*popt),'b-')
plt.plot(V1,I1,'k.-')
plt.show()
