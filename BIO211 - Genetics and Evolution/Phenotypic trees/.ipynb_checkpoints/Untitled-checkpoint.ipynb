# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('vaporeon.csv',delimiter=',')
Vap_Fla=df['Vap_Fla']
Vap_Gla=df['Vap_Gla']
Vap_Lea=df['Vap_Lea']
Vap_Bor=df['Vap_Bor']
Vap_Cal=df['Vap_Cal']
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  Vap_Fla  Unnamed: 4  Vap_Lea
# 0     Position       Base       Base        0         NaN        0  \
# 1            1          3          3        0         3.0        0
# 2            2          1          1        0         1.0        0
# 3            3          2          1        1         2.0        0
# 4            4          1          1        0         1.0        0
# ..         ...        ...        ...      ...         ...      ...
# 96          96          2          4        1         2.0        0
# 97          97          2          2        0         2.0        0
# 98          98          1          1        0         1.0        0
# 99          99          3          2        1         3.0        0
# 100        100          4          4        0         4.0        0
#
#      Unnamed: 6  Vap_Gla  Unnamed: 8  Vap_wat  Unnamed: 10  Vap_Cal
# 0           NaN        0         NaN        0          NaN        0  \
# ...

# %%
np.sum(Vap_Fla)
# Out:
# 26

# %%
np.sum(Vap_Gla)
# Out:
# 27

# %%
np.sum(Vap_Lea)
# Out:
# 22

# %%
np.sum(Vap_Bor)
# Out:
# 33
